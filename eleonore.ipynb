# %%
#bienvenue chez eleonore 

#Comment trouve-t-on les exoplanètes ? 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 

df = pd.read_csv("cleaned_data.csv")
df.hist("disc_year", bins = 10, color = 'lightblue');

# %%
plt.scatter(x = df['st_teff'], y = df['pl_bmasse'])
# Out:
# 0           NaN
# 1        4742.0
# 2        4874.0
# 3        4213.0
# 4           NaN
#           ...
# 36477       NaN
# 36478    4836.0
# 36479       NaN
# 36480    4780.0
# 36481    4841.0
# Name: st_teff, Length: 36482, dtype: float64

# %%
#by_method = df.groupby(by='discoverymethod')
#by_method.get_group('Radial Velocity')

#sns.pairplot(data=df, hue='discoverymethod');
df.dtypes
# Out:
# loc_rowid            int64
# pl_name             object
# hostname            object
# default_flag         int64
# sy_snum              int64
# sy_pnum              int64
# discoverymethod     object
# disc_year            int64
# disc_facility       object
# soltype             object
# pl_controv_flag      int64
# pl_refname          object
# pl_orbper          float64
# pl_orbsmax         float64
# pl_rade            float64
# pl_radj            float64
# pl_bmasse          float64
# pl_bmassj          float64
# pl_bmassprov        object
# pl_orbeccen        float64
# pl_insol           float64
# pl_eqt             float64
# ttv_flag             int64
# st_refname          object
# st_spectype         object
# st_teff            float64
# st_rad             float64
# st_mass            float64
# st_met             float64
# st_metratio         object
# st_logg            float64
# sy_refname          object
# rastr               object
# ra                 float64
# ...
