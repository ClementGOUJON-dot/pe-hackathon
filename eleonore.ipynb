# %%
#bienvenue chez eleonore 

#Comment trouve-t-on les exoplanètes ? 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 

df = pd.read_csv("cleaned_data.csv")
df.hist("disc_year", bins = 100, color = 'lightblue')
# Out:
# array([[<Axes: title={'center': 'disc_year'}>]], dtype=object)
