# %%
#Projet Solène Hackathon

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df= pd.read_csv("cleaned_data.csv")
df
# Out:
#        loc_rowid    pl_name hostname  default_flag  sy_snum  sy_pnum  \
# 0              1   11 Com b   11 Com             0        2        1
# 1              2   11 Com b   11 Com             0        2        1
# 2              3   11 Com b   11 Com             1        2        1
# 3              4   11 UMi b   11 UMi             1        1        1
# 4              5   11 UMi b   11 UMi             0        1        1
# ...          ...        ...      ...           ...      ...      ...
# 36477      36478  ups And d  ups And             0        2        3
# 36478      36479  ups Leo b  ups Leo             1        1        1
# 36479      36480   xi Aql b   xi Aql             0        1        1
# 36480      36481   xi Aql b   xi Aql             0        1        1
# 36481      36482   xi Aql b   xi Aql             1        1        1
#
#        discoverymethod  disc_year                           disc_facility  \
# 0      Radial Velocity       2007                        Xinglong Station
# 1      Radial Velocity       2007                        Xinglong Station
# 2      Radial Velocity       2007                        Xinglong Station
# 3      Radial Velocity       2009  Thueringer Landessternwarte Tautenburg
# 4      Radial Velocity       2009  Thueringer Landessternwarte Tautenburg
# ...                ...        ...                                     ...
# 36477  Radial Velocity       1999                  Multiple Observatories
# 36478  Radial Velocity       2021       Okayama Astrophysical Observatory
# 36479  Radial Velocity       2007       Okayama Astrophysical Observatory
# 36480  Radial Velocity       2007       Okayama Astrophysical Observatory
# 36481  Radial Velocity       2007       Okayama Astrophysical Observatory
#
#                    soltype  ...          ra         decstr        dec  \
# 0      Published Confirmed  ...  185.178779  +17d47m35.71s  17.793252
# 1      Published Confirmed  ...  185.178779  +17d47m35.71s  17.793252
# 2      Published Confirmed  ...  185.178779  +17d47m35.71s  17.793252
# 3      Published Confirmed  ...  229.274595  +71d49m26.19s  71.823943
# 4      Published Confirmed  ...  229.274595  +71d49m26.19s  71.823943
# ...                    ...  ...         ...            ...        ...
# 36477  Published Confirmed  ...   24.198353  +41d24m13.73s  41.403815
# 36478  Published Confirmed  ...  174.237219  -00d49m24.83s  -0.823564
# 36479  Published Confirmed  ...  298.562449  +08d27m39.98s   8.461105
# 36480  Published Confirmed  ...  298.562449  +08d27m39.98s   8.461105
# 36481  Published Confirmed  ...  298.562449  +08d27m39.98s   8.461105
#
#         sy_dist  sy_vmag  sy_kmag  sy_gaiamag   rowupdate pl_pubdate  \
# 0       93.1846  4.72307    2.282     4.44038  2014-07-23    2011-08
# 1       93.1846  4.72307    2.282     4.44038  2014-05-14    2008-01
# 2       93.1846  4.72307    2.282     4.44038  2023-09-19    2023-08
# 3      125.3210  5.01300    1.939     4.56216  2018-09-04    2017-03
# 4      125.3210  5.01300    1.939     4.56216  2018-04-25    2011-08
# ...         ...      ...      ...         ...         ...        ...
# 36477   13.4054  4.09565    2.859     3.98687  2014-08-21    2004-01
# 36478   52.5973  4.30490    2.184     4.03040  2022-01-10    2021-12
# 36479   56.1858  4.70964    2.171     4.42501  2014-07-23    2011-08
# 36480   56.1858  4.70964    2.171     4.42501  2014-05-14    2008-06
# 36481   56.1858  4.70964    2.171     4.42501  2023-09-19    2023-08
#
#        releasedate
# 0       2014-07-23
# 1       2014-05-14
# 2       2023-09-19
# 3       2018-09-06
# 4       2014-07-23
# ...            ...
# 36477   2014-08-21
# 36478   2022-01-10
# 36479   2014-07-23
# 36480   2014-05-14
# 36481   2023-09-19
#
# [36482 rows x 43 columns]

# %%
plt.scatter(df['disc_year'], df['pl_rade'], df['sy_dist'], marker='.', color='green')

# %%
plt.figure(figsize=(10, 6))
mask = df['st_teff'] < 15000

newdf= df[ df['st_teff']<10000]

scatter = plt.scatter(
    newdf['pl_orbper'], 
    newdf['pl_bmasse'], 
    c=newdf['st_teff'], 
    s=newdf['st_rad']*10,  # Multiplier pour ajuster la taille
    alpha=0.6, 
    cmap='jet'
)

# Ajouter une barre de couleur
plt.colorbar(scatter, label='Température d’équilibre (K)')
plt.xscale('log')
plt.yscale('log')
# Ajouter des labels et un titre
plt.xlabel('Période orbitale (jours)')
plt.ylabel('Masse * sin(i)')
plt.title('Masse*sin(i) en fonction de la période orbitale')
# Out:
# Text(0.5, 1.0, 'Masse*sin(i) en fonction de la période orbitale')
