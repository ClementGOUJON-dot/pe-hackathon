# %%
#bienvenue chez eleonore 

#Comment trouve-t-on les exoplanètes ? 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 

df = pd.read_csv("cleaned_data.csv")
df.hist("disc_year", bins = 10, color = 'lightblue');

# %%
plt.scatter(x = df['st_teff'], y = df['pl_bmasse'])

# %%
df.dtypes
# Out:
# loc_rowid            int64
# pl_name             object
# hostname            object
# default_flag         int64
# sy_snum              int64
# sy_pnum              int64
# discoverymethod     object
# disc_year            int64
# disc_facility       object
# soltype             object
# pl_controv_flag      int64
# pl_refname          object
# pl_orbper          float64
# pl_orbsmax         float64
# pl_rade            float64
# pl_radj            float64
# pl_bmasse          float64
# pl_bmassj          float64
# pl_bmassprov        object
# pl_orbeccen        float64
# pl_insol           float64
# pl_eqt             float64
# ttv_flag             int64
# st_refname          object
# st_spectype         object
# st_teff            float64
# st_rad             float64
# st_mass            float64
# st_met             float64
# st_metratio         object
# st_logg            float64
# sy_refname          object
# rastr               object
# ra                 float64
# decstr              object
# dec                float64
# sy_dist            float64
# sy_vmag            float64
# sy_kmag            float64
# sy_gaiamag         float64
# rowupdate           object
# pl_pubdate          object
# releasedate         object
# dtype: object

# %%
by_method = df.groupby('discoverymethod')
by_method.size()

counts = by_method.size()

counts.plot(kind='bar')

plt.title('Nombre de planètes découvertes par méthode')
plt.xlabel('méthode')
plt.ylabel('Nombre dexoplanètes découvertes')
plt.xticks(rotation=90)

# Affichage
plt.show()
#sns.relplot(data=df, x='total_bill', y='tip', col='time', row='day', hue='sex', size='size', style='smoker',);

# %%
newdf = df[df['discoverymethod'] != 'Transit']

sns.barplot(x=newdf['disc_year'], y=newdf.groupby('disc_year').size(), hue = newdf['discoverymethod'], ci = None, width = 10)
plt.ylabel('count')
plt.xlabel('année de découverte')
plt.xticks(rotation = 90);
# Out:
# C:\Users\elele\AppData\Local\Temp\ipykernel_45148\3182948307.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=newdf['disc_year'], y=newdf.groupby('disc_year').size(), hue = newdf['discoverymethod'], ci = None, width = 10)

# %%
by_method = df.groupby('discoverymethod')
by_method.size()
# Out:
# discoverymethod
# Astrometry                           3
# Disk Kinematics                      1
# Eclipse Timing Variations           24
# Imaging                            147
# Microlensing                       689
# Orbital Brightness Modulation       21
# Pulsar Timing                       13
# Pulsation Timing Variations          2
# Radial Velocity                   2569
# Transit                          32870
# Transit Timing Variations          143
# dtype: int64

# %%
newdf2
# Out:
#        loc_rowid                  pl_name                 hostname  \
# 27            28  1RXS J160929.1-210524 b    1RXS J160929.1-210524
# 28            29  1RXS J160929.1-210524 b    1RXS J160929.1-210524
# 29            30  1RXS J160929.1-210524 b    1RXS J160929.1-210524
# 30            31  1RXS J160929.1-210524 b    1RXS J160929.1-210524
# 35            36                 2M0437 b  2MASS J04372171+2651014
# ...          ...                      ...                      ...
# 36432      36433                 pi Men c                 HD 39091
# 36433      36434                 pi Men c                 HD 39091
# 36434      36435                 pi Men c                 HD 39091
# 36435      36436                 pi Men c                 HD 39091
# 36436      36437                 pi Men c                 HD 39091
#
#        default_flag  sy_snum  sy_pnum discoverymethod  disc_year  \
# 27                0        1        1         Imaging       2008
# 28                1        1        1         Imaging       2008
# 29                0        1        1         Imaging       2008
# 30                0        1        1         Imaging       2008
# 35                1        1        1         Imaging       2021
# ...             ...      ...      ...             ...        ...
# 36432             1        1        3         Transit       2018
# 36433             0        1        3         Transit       2018
# 36434             0        1        3         Transit       2018
# 36435             0        1        3         Transit       2018
# 36436             0        1        3         Transit       2018
#
#                                       disc_facility                 soltype  \
# 27                               Gemini Observatory     Published Confirmed
# 28                               Gemini Observatory     Published Confirmed
# 29                               Gemini Observatory     Published Confirmed
# 30                               Gemini Observatory     Published Confirmed
# 35                                 Subaru Telescope     Published Confirmed
# ...                                             ...                     ...
# 36432  Transiting Exoplanet Survey Satellite (TESS)     Published Confirmed
# 36433  Transiting Exoplanet Survey Satellite (TESS)     Published Confirmed
# 36434  Transiting Exoplanet Survey Satellite (TESS)     Published Confirmed
# 36435  Transiting Exoplanet Survey Satellite (TESS)  TESS Project Candidate
# 36436  Transiting Exoplanet Survey Satellite (TESS)     Published Confirmed
#
#        ...          ra         decstr        dec   sy_dist  sy_vmag  sy_kmag  \
# 27     ...  242.376234  -21d04m59.31s -21.083140  139.1350   12.618    8.916
# 28     ...  242.376234  -21d04m59.31s -21.083140  139.1350   12.618    8.916
# 29     ...  242.376234  -21d04m59.31s -21.083140  139.1350   12.618    8.916
# 30     ...  242.376234  -21d04m59.31s -21.083140  139.1350   12.618    8.916
# 35     ...   69.340553  +26d51m01.08s  26.850300  128.4840   16.186   10.386
# ...    ...         ...            ...        ...       ...      ...      ...
# 36432  ...   84.299280  -80d27m52.57s -80.464604   18.2702    5.650    4.241
# 36433  ...   84.299280  -80d27m52.57s -80.464604   18.2702    5.650    4.241
# 36434  ...   84.299280  -80d27m52.57s -80.464604   18.2702    5.650    4.241
# 36435  ...   84.299280  -80d27m52.57s -80.464604   18.2702    5.650    4.241
# 36436  ...   84.299280  -80d27m52.57s -80.464604   18.2702    5.650    4.241
#
#        sy_gaiamag   rowupdate pl_pubdate  releasedate
# 27        12.0572  2015-04-01    2015-03   2015-04-01
# 28        12.0572  2015-04-01    2015-03   2015-04-01
# 29        12.0572  2015-04-01    2010-08   2015-04-01
# 30        12.0572  2014-05-14    2008-12   2014-05-14
# 35        14.3374  2021-12-13    2021-10   2021-12-13
# ...           ...         ...        ...          ...
# 36432      5.5128  2023-06-14    2022-09   2023-06-14
# 36433      5.5128  2024-03-04    2023-03   2024-03-04
# 36434      5.5128  2018-11-26    2018-11   2018-11-29
# 36435      5.5128  2023-04-10    2017-07   2023-04-10
# 36436      5.5128  2022-05-03    2022-05   2022-05-03
#
# [33913 rows x 43 columns]

# %%
data = pd.read_csv('cleaned_data.csv')

by_year_and_method = data.groupby(['disc_year', 'discoverymethod'])
data_counts = by_year_and_method.size().reset_index(name='discoveries')

by_method = data_counts.groupby('discoverymethod')
data_counts['cumulative_discoveries'] = by_method['discoveries'].cumsum()

last_year_counts = data_counts[data_counts['disc_year'] == data_counts['disc_year'].max()]

sorted_methods = last_year_counts.sort_values('cumulative_discoveries')['discoverymethod'].tolist()

plt.figure()
sns.histplot(data=data_counts, x="disc_year", weights="cumulative_discoveries", hue="discoverymethod",
             hue_order=sorted_methods, multiple="stack", palette="Set2", bins=30)

plt.xlabel("Année de Découverte")
plt.ylabel("Nombre Cumulé Total de Planètes Découvertes")
plt.title("Évolution Cumulative des Découvertes de Planètes par Méthode de Découverte (Ordre Croissant à la Fin)")

plt.show()
